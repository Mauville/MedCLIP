# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauville/MedCLIP/blob/main/dataStats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Statistics
# Get information on the dataset

# %%
import pandas as pd
import plotly.express as px

from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/Shareddrives/DeepLearning/datav2/trimmed.csv')  

pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', 50)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Tomar de Core_modality , Ct, Xr, MR., hacer prueba inicial codificar primera version.

# %%
len(df)

print(df.info())

print(df.describe(include='all', datetime_is_numeric=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26384 entries, 0 to 26383
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Diagnosis       26384 non-null  object
#  1   Caption         26378 non-null  object
#  2   Core_Modality   26384 non-null  object
#  3   Full_Modality   26384 non-null  object
#  4   Case_Diagnosis  26384 non-null  object
#  5   Diagnosis_By    23512 non-null  object
#  6   Location        24565 non-null  object
#  7   Category        24537 non-null  object
#  8   Keywords        22535 non-null  object
#  9   filename        26384 non-null  object
# dtypes: object(10)
# memory usage: 2.0+ MB
# None
#          Diagnosis Caption Core_Modality    Full_Modality Case_Diagnosis Diagnosis_By         Location Category                                Keywords          filename
# ...

# %% [markdown]
# Diferentes estrategias. Como llenar con la moda.
#
# Informacion:
#
# - Necesitamos la modalidad que es la referencia.
# - Se necesita diagnosis.
# - Caption

# %%
df.isnull().sum()
# Out:
# Diagnosis            0
# Caption              6
# Core_Modality        0
# Full_Modality        0
# Case_Diagnosis       0
# Diagnosis_By      2872
# Location          1819
# Category          1847
# Keywords          3849
# filename             0
# dtype: int64

# %%
sam = df.sample(n=10)
print(sam[['Core_Modality', 'Diagnosis', 'Caption']])
# Out:
#       Core_Modality                                          Diagnosis                                            Caption
# 12419            MR         Intracranial epidermoid cyst (retroclival)  Corresponding apparent diffusion coefficient m...
# 19107            CT  Pilocytic Astrocytoma (WHO 1), temporal lobe, ...  Complex left temporal lobe mass with extension...
# 14202            MR  Lumbar Spine, Epidural Abscess with Osteomyeli...  Hyperintense mass anterior to the thecal sac a...
# 21764            CT  Right C6 radiculopathy and Ankylosing Spondylitis  CT Cervical Spine one year prior to the curren...
# 14212            MR  Lumbosacral dysgenesis (syndrome of caudal reg...  Club shaped conus medullaris.\nNo tethering of...
# 15704            XR                               Mitral Regurgitation  A PA image of the chest demonstrates cardiomeg...
# 7464             MR                      Desmoplastic  medulloblastoma  Large heterogeneous cerebellar mass with cysti...
# ...

# %%
fic = px.histogram(df, x="Core_Modality")
fic.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e43d11f-911f-4796-9b6e-c7a4e74ac059" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e43d11f-911f-4796-9b6e-c7a4e74ac059")) {
#                     Plotly.newPlot(
#                         '1e43d11f-911f-4796-9b6e-c7a4e74ac059',
# ...

# %%
# Here we use a column with categorical data
fig = px.histogram(df, x="Location" )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e09c27fb-2a7a-4a14-9af0-f78b8d9bfc5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e09c27fb-2a7a-4a14-9af0-f78b8d9bfc5b")) {
#                     Plotly.newPlot(
#                         'e09c27fb-2a7a-4a14-9af0-f78b8d9bfc5b',
# ...

# %%
# Here we use a column with categorical data
fig = px.histogram(df, x="Category")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0e1789a6-d5e7-4016-ba60-7736fd8afe2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0e1789a6-d5e7-4016-ba60-7736fd8afe2d")) {
#                     Plotly.newPlot(
#                         '0e1789a6-d5e7-4016-ba60-7736fd8afe2d',
# ...
