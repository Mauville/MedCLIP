# %%
# !pip install tqdm
# !pip install pandas

# %%
from tqdm import tqdm
import pandas as pd
import urllib.request

df = pd.DataFrame(pd.read_excel(r'/content/drive/Shareddrives/DeepLearning/MedCLIP/Data/Dataset_MedPix_V1.xlsx'))

for url in tqdm(df["Image_URL"]):
    filename = url.split("/")[-1]
    urllib.request.urlretrieve(url, f"/content/drive/Shareddrives/DeepLearning/data/output/{filename}")
# Out:
# 100%|██████████| 36611/36611 [55:58<00:00, 10.90it/s]
